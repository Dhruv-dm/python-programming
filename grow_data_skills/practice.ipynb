# %%
a = 1

if a:
    print('ho gya')
else:
    print('nhi hua')
# Out:
# ho gya

# %%
a = [1,2,3]
b = [1,2,3]

print(a is b)
# Out:
# False

# %%
print(id(a))
print(id(b))
# Out:
# 1864655392128
# 1864655020480

# %%
a = True
b = False

print(a and b)
# Out:
# False
